# %% [markdown]
# ## Analytical Data Mining: Homework 5
# **Name**: Advait Ramesh Iyer
#
# **NetID**: aiyer01 **|** **SUID:** 330623485

# %% [markdown]
# ### Question 3
#
# Flajolet Martin Algorithm:

# %% [markdown]
# **Step 1:** Imported all the necessary packages, and retrieved file list.

# %%
import glob
import pyhash
import sklearn
import numpy as np
import csv
from sklearn.utils.murmurhash import murmurhash3_32
files = glob.glob("./*.txt")
files
# Out:
# ['./quotes_2009-01.txt',
#  './quotes_2009-02.txt',
#  './quotes_2009-03.txt',
#  './quotes_2009-04.txt',
#  './quotes_2008-09.txt',
#  './quotes_2008-08.txt',
#  './quotes_2008-11.txt',
#  './quotes_2008-10.txt',
#  './quotes_2008-12.txt']

# %% [markdown]
# **Step 2:** Built hasher function, which filters only quotes. It then calculates the trailing zeros in the output of Murmur Hash on each quote.

# %%
def Hasher(files):
    for f in files:
        with open(f) as fval:
            while(True):
                line = fval.readline()
                if not line:
                    break
                if len(line) == 0:
                    continue
                if line[0] == "Q":
                    temp = []
                    for i in range(40):
                        murmur = murmurhash3_32(line, positive = True, seed = i)
                        bin_murmur = bin(murmur)
                        trail_murmur = len(bin_murmur[2:]) - (bin_murmur[2:].rfind("1") + 1)
                        temp.append(trail_murmur)
                    yield temp
                    
Rs = Hasher(files)
Rs
# Out:
# <generator object Hasher at 0xa1f1d1a50>

# %% [markdown]
# **Step 3:** Processed chunks of 200,000 lines, and calculated the max number of trailing zeros in each chunk.

# %%
max_zero = [-1 for i in range(40)]
ctr = 0
for R in Rs:
    if ctr % 200000 == 0:
        print("{} lines processed".format(ctr)) 
    ctr += 1
    for j in range(40):
        if R[j] > max_zero[j]:
            max_zero[j] = R[j]
# Out:
# 0 lines processed
# 200000 lines processed
# 400000 lines processed
# 600000 lines processed
# 800000 lines processed
# 1000000 lines processed
# 1200000 lines processed
# 1400000 lines processed
# 1600000 lines processed
# 1800000 lines processed
# 2000000 lines processed
# 2200000 lines processed
# 2400000 lines processed
# 2600000 lines processed
# 2800000 lines processed
# 3000000 lines processed
# 3200000 lines processed
# 3400000 lines processed
# 3600000 lines processed
# 3800000 lines processed
# 4000000 lines processed
# 4200000 lines processed
# 4400000 lines processed
# 4600000 lines processed
# 4800000 lines processed
# 5000000 lines processed
# 5200000 lines processed
# 5400000 lines processed
# 5600000 lines processed
# 5800000 lines processed
# 6000000 lines processed
# 6200000 lines processed
# 6400000 lines processed
# 6600000 lines processed
# 6800000 lines processed
# 7000000 lines processed
# 7200000 lines processed
# 7400000 lines processed
# 7600000 lines processed
# 7800000 lines processed
# 8000000 lines processed
# 8200000 lines processed
# 8400000 lines processed
# 8600000 lines processed
# 8800000 lines processed
# 9000000 lines processed
# 9200000 lines processed
# 9400000 lines processed
# 9600000 lines processed
# 9800000 lines processed
# 10000000 lines processed
# 10200000 lines processed
# 10400000 lines processed
# 10600000 lines processed
# 10800000 lines processed
# 11000000 lines processed
# 11200000 lines processed
# 11400000 lines processed
# 11600000 lines processed
# 11800000 lines processed
# 12000000 lines processed
# 12200000 lines processed
# 12400000 lines processed
# 12600000 lines processed
# 12800000 lines processed
# 13000000 lines processed
# 13200000 lines processed
# 13400000 lines processed
# 13600000 lines processed
# 13800000 lines processed
# 14000000 lines processed
# 14200000 lines processed
# 14400000 lines processed
# 14600000 lines processed
# 14800000 lines processed
# 15000000 lines processed
# 15200000 lines processed
# 15400000 lines processed
# 15600000 lines processed
# 15800000 lines processed
# 16000000 lines processed
# 16200000 lines processed
# 16400000 lines processed
# 16600000 lines processed
# 16800000 lines processed
# 17000000 lines processed
# 17200000 lines processed
# 17400000 lines processed
# 17600000 lines processed
# 17800000 lines processed
# 18000000 lines processed
# 18200000 lines processed
# 18400000 lines processed
# 18600000 lines processed
# 18800000 lines processed
# 19000000 lines processed
# 19200000 lines processed
# 19400000 lines processed
# 19600000 lines processed
# 19800000 lines processed
# 20000000 lines processed
# 20200000 lines processed
# 20400000 lines processed
# 20600000 lines processed
# 20800000 lines processed
# 21000000 lines processed
# 21200000 lines processed
# 21400000 lines processed
# 21600000 lines processed
# 21800000 lines processed
# 22000000 lines processed
# 22200000 lines processed
# 22400000 lines processed
# 22600000 lines processed
# 22800000 lines processed
# 23000000 lines processed
# 23200000 lines processed
# 23400000 lines processed
# 23600000 lines processed
# 23800000 lines processed
# 24000000 lines processed
# 24200000 lines processed
# 24400000 lines processed
# 24600000 lines processed
# 24800000 lines processed
# 25000000 lines processed
# 25200000 lines processed
# 25400000 lines processed
# 25600000 lines processed
# 25800000 lines processed
# 26000000 lines processed
# 26200000 lines processed
# 26400000 lines processed
# 26600000 lines processed
# 26800000 lines processed
# 27000000 lines processed
# 27200000 lines processed
# 27400000 lines processed
# 27600000 lines processed
# 27800000 lines processed
# 28000000 lines processed
# 28200000 lines processed
# 28400000 lines processed
# 28600000 lines processed
# 28800000 lines processed
# 29000000 lines processed
# 29200000 lines processed
# 29400000 lines processed
# 29600000 lines processed
# 29800000 lines processed
# 30000000 lines processed
# 30200000 lines processed
# 30400000 lines processed
# 30600000 lines processed
# 30800000 lines processed
# 31000000 lines processed
# 31200000 lines processed
# 31400000 lines processed
# 31600000 lines processed
# 31800000 lines processed
# 32000000 lines processed
# 32200000 lines processed
# 32400000 lines processed
# 32600000 lines processed
# 32800000 lines processed
# 33000000 lines processed
# 33200000 lines processed
# 33400000 lines processed
# 33600000 lines processed
# 33800000 lines processed
# 34000000 lines processed
# 34200000 lines processed
# 34400000 lines processed
# 34600000 lines processed
# 34800000 lines processed
# 35000000 lines processed
# 35200000 lines processed
# 35400000 lines processed
# 35600000 lines processed
# 35800000 lines processed
# 36000000 lines processed
# 36200000 lines processed
# 36400000 lines processed
# 36600000 lines processed
# 36800000 lines processed
# 37000000 lines processed
# 37200000 lines processed
# 37400000 lines processed
# 37600000 lines processed
# 37800000 lines processed
# 38000000 lines processed
# 38200000 lines processed
# 38400000 lines processed
# 38600000 lines processed
# 38800000 lines processed
# 39000000 lines processed
# 39200000 lines processed
# 39400000 lines processed
# 39600000 lines processed
# 39800000 lines processed
# 40000000 lines processed
# 40200000 lines processed
# 40400000 lines processed
# 40600000 lines processed
# 40800000 lines processed
# 41000000 lines processed
# 41200000 lines processed
# 41400000 lines processed
# 41600000 lines processed
# 41800000 lines processed
# 42000000 lines processed
# 42200000 lines processed
# 42400000 lines processed
# 42600000 lines processed
# 42800000 lines processed
# 43000000 lines processed
# 43200000 lines processed
# 43400000 lines processed
# 43600000 lines processed
# 43800000 lines processed
# 44000000 lines processed
# 44200000 lines processed
# 44400000 lines processed
# 44600000 lines processed
# 44800000 lines processed
# 45000000 lines processed
# 45200000 lines processed
# 45400000 lines processed
# 45600000 lines processed
# 45800000 lines processed
# 46000000 lines processed
# 46200000 lines processed
# 46400000 lines processed
# 46600000 lines processed
# 46800000 lines processed
# 47000000 lines processed
# 47200000 lines processed
# 47400000 lines processed
# 47600000 lines processed
# 47800000 lines processed
# 48000000 lines processed
# 48200000 lines processed
# 48400000 lines processed
# 48600000 lines processed
# 48800000 lines processed
# 49000000 lines processed
# 49200000 lines processed
# 49400000 lines processed
# 49600000 lines processed
# 49800000 lines processed
# 50000000 lines processed
# 50200000 lines processed
# 50400000 lines processed
# 50600000 lines processed
# 50800000 lines processed
# 51000000 lines processed
# 51200000 lines processed
# 51400000 lines processed
# 51600000 lines processed
# 51800000 lines processed
# 52000000 lines processed
# 52200000 lines processed
# 52400000 lines processed
# 52600000 lines processed
# 52800000 lines processed
# 53000000 lines processed
# 53200000 lines processed
# 53400000 lines processed
# 53600000 lines processed
# 53800000 lines processed
# 54000000 lines processed
# 54200000 lines processed
# 54400000 lines processed
# 54600000 lines processed
# 54800000 lines processed
# 55000000 lines processed
# 55200000 lines processed
# 55400000 lines processed
# 55600000 lines processed
# 55800000 lines processed
# 56000000 lines processed
# 56200000 lines processed
# 56400000 lines processed
# 56600000 lines processed
# 56800000 lines processed
# 57000000 lines processed
# 57200000 lines processed
# 57400000 lines processed
# 57600000 lines processed
# 57800000 lines processed
# 58000000 lines processed
# 58200000 lines processed
# 58400000 lines processed
# 58600000 lines processed
# 58800000 lines processed
# 59000000 lines processed
# 59200000 lines processed
# 59400000 lines processed
# 59600000 lines processed
# 59800000 lines processed
# 60000000 lines processed
# 60200000 lines processed
# 60400000 lines processed
# 60600000 lines processed
# 60800000 lines processed
# 61000000 lines processed
# 61200000 lines processed
# 61400000 lines processed
# 61600000 lines processed
# 61800000 lines processed
# 62000000 lines processed
# 62200000 lines processed
# 62400000 lines processed
# 62600000 lines processed
# 62800000 lines processed
# 63000000 lines processed
# 63200000 lines processed
# 63400000 lines processed
# 63600000 lines processed
# 63800000 lines processed
# 64000000 lines processed
# 64200000 lines processed
# 64400000 lines processed
# 64600000 lines processed
# 64800000 lines processed
# 65000000 lines processed
# 65200000 lines processed
# 65400000 lines processed
# 65600000 lines processed
# 65800000 lines processed
# 66000000 lines processed
# 66200000 lines processed
# 66400000 lines processed
# 66600000 lines processed
# 66800000 lines processed
# 67000000 lines processed
# 67200000 lines processed
# 67400000 lines processed
# 67600000 lines processed
# 67800000 lines processed
# 68000000 lines processed
# 68200000 lines processed
# 68400000 lines processed
# 68600000 lines processed
# 68800000 lines processed
# 69000000 lines processed
# 69200000 lines processed
# 69400000 lines processed
# 69600000 lines processed
# 69800000 lines processed
# 70000000 lines processed
# 70200000 lines processed
# 70400000 lines processed
# 70600000 lines processed
# 70800000 lines processed
# 71000000 lines processed
# 71200000 lines processed
# 71400000 lines processed
# 71600000 lines processed
# 71800000 lines processed
# 72000000 lines processed
# 72200000 lines processed
# 72400000 lines processed
# 72600000 lines processed
# 72800000 lines processed
# 73000000 lines processed
# 73200000 lines processed
# 73400000 lines processed
# 73600000 lines processed
# 73800000 lines processed
# 74000000 lines processed
# 74200000 lines processed
# 74400000 lines processed
# 74600000 lines processed
# 74800000 lines processed
# 75000000 lines processed
# 75200000 lines processed
# 75400000 lines processed
# 75600000 lines processed
# 75800000 lines processed
# 76000000 lines processed
# 76200000 lines processed
# 76400000 lines processed
# 76600000 lines processed
# 76800000 lines processed
# 77000000 lines processed
# 77200000 lines processed
# 77400000 lines processed
# 77600000 lines processed
# 77800000 lines processed
# 78000000 lines processed
# 78200000 lines processed
# 78400000 lines processed
# 78600000 lines processed
# 78800000 lines processed
# 79000000 lines processed
# 79200000 lines processed
# 79400000 lines processed
# 79600000 lines processed
# 79800000 lines processed
# 80000000 lines processed
# 80200000 lines processed
# 80400000 lines processed
# 80600000 lines processed
# 80800000 lines processed
# 81000000 lines processed
# 81200000 lines processed
# 81400000 lines processed
# 81600000 lines processed
# 81800000 lines processed
# 82000000 lines processed
# 82200000 lines processed
# 82400000 lines processed
# 82600000 lines processed
# 82800000 lines processed
# 83000000 lines processed
# 83200000 lines processed
# 83400000 lines processed
# 83600000 lines processed
# 83800000 lines processed
# 84000000 lines processed
# 84200000 lines processed
# 84400000 lines processed
# 84600000 lines processed
# 84800000 lines processed
# 85000000 lines processed
# 85200000 lines processed
# 85400000 lines processed
# 85600000 lines processed
# 85800000 lines processed
# 86000000 lines processed
# 86200000 lines processed
# 86400000 lines processed
# 86600000 lines processed
# 86800000 lines processed
# 87000000 lines processed
# 87200000 lines processed
# 87400000 lines processed
# 87600000 lines processed
# 87800000 lines processed
# 88000000 lines processed
# 88200000 lines processed
# 88400000 lines processed
# 88600000 lines processed
# 88800000 lines processed
# 89000000 lines processed
# 89200000 lines processed
# 89400000 lines processed
# 89600000 lines processed
# 89800000 lines processed
# 90000000 lines processed
# 90200000 lines processed
# 90400000 lines processed
# 90600000 lines processed
# 90800000 lines processed
# 91000000 lines processed
# 91200000 lines processed
# 91400000 lines processed
# 91600000 lines processed
# 91800000 lines processed
# 92000000 lines processed
# 92200000 lines processed
# 92400000 lines processed
# 92600000 lines processed
# 92800000 lines processed
# 93000000 lines processed
# 93200000 lines processed
# 93400000 lines processed
# 93600000 lines processed
# 93800000 lines processed
# 94000000 lines processed
# 94200000 lines processed
# 94400000 lines processed
# 94600000 lines processed
# 94800000 lines processed
# 95000000 lines processed
# 95200000 lines processed
# 95400000 lines processed
# 95600000 lines processed
# 95800000 lines processed
# 96000000 lines processed
# 96200000 lines processed
# 96400000 lines processed
# 96600000 lines processed
# 96800000 lines processed
# 97000000 lines processed
# 97200000 lines processed
# 97400000 lines processed
# 97600000 lines processed
# 97800000 lines processed
# 98000000 lines processed
# 98200000 lines processed
# 98400000 lines processed
# 98600000 lines processed
# 98800000 lines processed
# 99000000 lines processed
# 99200000 lines processed
# 99400000 lines processed
# 99600000 lines processed
# 99800000 lines processed
# 100000000 lines processed
# 100200000 lines processed
# 100400000 lines processed
# 100600000 lines processed
# 100800000 lines processed
# 101000000 lines processed
# 101200000 lines processed
# 101400000 lines processed
# 101600000 lines processed
# 101800000 lines processed
# 102000000 lines processed
# 102200000 lines processed
# 102400000 lines processed
# 102600000 lines processed
# 102800000 lines processed
# 103000000 lines processed
# 103200000 lines processed
# 103400000 lines processed
# 103600000 lines processed
# 103800000 lines processed
# 104000000 lines processed
# 104200000 lines processed
# 104400000 lines processed
# 104600000 lines processed
# 104800000 lines processed
# 105000000 lines processed
# 105200000 lines processed
# 105400000 lines processed
# 105600000 lines processed
# 105800000 lines processed
# 106000000 lines processed
# 106200000 lines processed
# 106400000 lines processed
# 106600000 lines processed
# 106800000 lines processed
# 107000000 lines processed
# 107200000 lines processed
# 107400000 lines processed
# 107600000 lines processed
# 107800000 lines processed
# 108000000 lines processed
# 108200000 lines processed
# 108400000 lines processed
# 108600000 lines processed
# 108800000 lines processed
# 109000000 lines processed
# 109200000 lines processed
# 109400000 lines processed
# 109600000 lines processed
# 109800000 lines processed
# 110000000 lines processed
# 110200000 lines processed
# 110400000 lines processed
# 110600000 lines processed
# 110800000 lines processed
# 111000000 lines processed
# 111200000 lines processed
# 111400000 lines processed
# 111600000 lines processed
# 111800000 lines processed
# 112000000 lines processed
# 112200000 lines processed
# 112400000 lines processed
# 112600000 lines processed
# 112800000 lines processed
# 113000000 lines processed
# 113200000 lines processed
# 113400000 lines processed
# 113600000 lines processed
# 113800000 lines processed
# 114000000 lines processed
# 114200000 lines processed
# 114400000 lines processed
# 114600000 lines processed
# 114800000 lines processed
# 115000000 lines processed
# 115200000 lines processed
# 115400000 lines processed
# 115600000 lines processed
# 115800000 lines processed
# 116000000 lines processed
# 116200000 lines processed
# 116400000 lines processed
# 116600000 lines processed
# 116800000 lines processed
# 117000000 lines processed
# 117200000 lines processed
# 117400000 lines processed
# 117600000 lines processed
# 117800000 lines processed
# 118000000 lines processed
# 118200000 lines processed
# 118400000 lines processed
# 118600000 lines processed
# 118800000 lines processed
# 119000000 lines processed
# 119200000 lines processed
# 119400000 lines processed
# 119600000 lines processed
# 119800000 lines processed
# 120000000 lines processed
# 120200000 lines processed
# 120400000 lines processed
# 120600000 lines processed
# 120800000 lines processed
# 121000000 lines processed
# 121200000 lines processed
# 121400000 lines processed
# 121600000 lines processed
# 121800000 lines processed
# 122000000 lines processed
# 122200000 lines processed
# 122400000 lines processed
# 122600000 lines processed
# 122800000 lines processed
# 123000000 lines processed
# 123200000 lines processed
# 123400000 lines processed
# 123600000 lines processed
# 123800000 lines processed
# 124000000 lines processed
# 124200000 lines processed
# 124400000 lines processed
# 124600000 lines processed
# 124800000 lines processed
# 125000000 lines processed
# 125200000 lines processed
# 125400000 lines processed
# 125600000 lines processed
# 125800000 lines processed
# 126000000 lines processed
# 126200000 lines processed
# 126400000 lines processed
# 126600000 lines processed
# 126800000 lines processed
# 127000000 lines processed
# 127200000 lines processed
# 127400000 lines processed
# 127600000 lines processed
# 127800000 lines processed
# 128000000 lines processed
# 128200000 lines processed
# 128400000 lines processed
# 128600000 lines processed
# 128800000 lines processed
# 129000000 lines processed
# 129200000 lines processed
# 129400000 lines processed
# 129600000 lines processed
# 129800000 lines processed
# 130000000 lines processed
# 130200000 lines processed
# 130400000 lines processed
# 130600000 lines processed
# 130800000 lines processed
# 131000000 lines processed
# 131200000 lines processed
# 131400000 lines processed
# 131600000 lines processed
# 131800000 lines processed
# 132000000 lines processed
# 132200000 lines processed
# 132400000 lines processed
# 132600000 lines processed
# 132800000 lines processed
# 133000000 lines processed
# 133200000 lines processed
# 133400000 lines processed
# 133600000 lines processed
# 133800000 lines processed
# 134000000 lines processed
# 134200000 lines processed
# 134400000 lines processed
# 134600000 lines processed
# 134800000 lines processed
# 135000000 lines processed
# 135200000 lines processed
# 135400000 lines processed
# 135600000 lines processed
# 135800000 lines processed
# 136000000 lines processed
# 136200000 lines processed
# 136400000 lines processed
# 136600000 lines processed
# 136800000 lines processed
# 137000000 lines processed
# 137200000 lines processed
# 137400000 lines processed
# 137600000 lines processed
# 137800000 lines processed
# 138000000 lines processed
# 138200000 lines processed
# 138400000 lines processed
# 138600000 lines processed
# 138800000 lines processed
# 139000000 lines processed
# 139200000 lines processed
# 139400000 lines processed
# 139600000 lines processed
# 139800000 lines processed
# 140000000 lines processed
# 140200000 lines processed
# 140400000 lines processed
# 140600000 lines processed
# 140800000 lines processed
# 141000000 lines processed
# 141200000 lines processed
# 141400000 lines processed
# 141600000 lines processed
# 141800000 lines processed
# 142000000 lines processed
# 142200000 lines processed
# 142400000 lines processed
# 142600000 lines processed
# 142800000 lines processed
# 143000000 lines processed
# 143200000 lines processed
# 143400000 lines processed
# 143600000 lines processed
# 143800000 lines processed
# 144000000 lines processed
# 144200000 lines processed
# 144400000 lines processed
# 144600000 lines processed
# 144800000 lines processed
# 145000000 lines processed
# 145200000 lines processed
# 145400000 lines processed
# 145600000 lines processed
# 145800000 lines processed
# 146000000 lines processed
# 146200000 lines processed
# 146400000 lines processed
# 146600000 lines processed
# 146800000 lines processed
# 147000000 lines processed
# 147200000 lines processed
# 147400000 lines processed
# 147600000 lines processed
# 147800000 lines processed
# 148000000 lines processed
# 148200000 lines processed
# 148400000 lines processed
# 148600000 lines processed
# 148800000 lines processed
# 149000000 lines processed
# 149200000 lines processed
# 149400000 lines processed
# 149600000 lines processed
# 149800000 lines processed
# 150000000 lines processed
# 150200000 lines processed
# 150400000 lines processed
# 150600000 lines processed
# 150800000 lines processed
# 151000000 lines processed
# 151200000 lines processed
# 151400000 lines processed
# 151600000 lines processed
# 151800000 lines processed
# 152000000 lines processed
# 152200000 lines processed
# 152400000 lines processed
# 152600000 lines processed
# 152800000 lines processed
# 153000000 lines processed
# 153200000 lines processed
# 153400000 lines processed
# 153600000 lines processed
# 153800000 lines processed
# 154000000 lines processed
# 154200000 lines processed
# 154400000 lines processed
# 154600000 lines processed
# 154800000 lines processed
# 155000000 lines processed
# 155200000 lines processed
# 155400000 lines processed
# 155600000 lines processed
# 155800000 lines processed
# 156000000 lines processed
# 156200000 lines processed
# 156400000 lines processed
# 156600000 lines processed
# 156800000 lines processed
# 157000000 lines processed
# 157200000 lines processed
# 157400000 lines processed
# 157600000 lines processed
# 157800000 lines processed
# 158000000 lines processed
# 158200000 lines processed
# 158400000 lines processed
# 158600000 lines processed
# 158800000 lines processed
# 159000000 lines processed
# 159200000 lines processed
# 159400000 lines processed
# 159600000 lines processed
# 159800000 lines processed
# 160000000 lines processed
# 160200000 lines processed
# 160400000 lines processed
# 160600000 lines processed
# 160800000 lines processed
# 161000000 lines processed
# 161200000 lines processed
# 161400000 lines processed
# 161600000 lines processed
# 161800000 lines processed
# 162000000 lines processed
# 162200000 lines processed
# 162400000 lines processed
# 162600000 lines processed
# 162800000 lines processed
# 163000000 lines processed
# 163200000 lines processed
# 163400000 lines processed
# 163600000 lines processed
# 163800000 lines processed
# 164000000 lines processed
# 164200000 lines processed
# 164400000 lines processed
# 164600000 lines processed
# 164800000 lines processed
# 165000000 lines processed
# 165200000 lines processed
# 165400000 lines processed
# 165600000 lines processed
# 165800000 lines processed
# 166000000 lines processed
# 166200000 lines processed
# 166400000 lines processed
# 166600000 lines processed
# 166800000 lines processed
# 167000000 lines processed
# 167200000 lines processed
# 167400000 lines processed
# 167600000 lines processed
# 167800000 lines processed
# 168000000 lines processed
# 168200000 lines processed
# 168400000 lines processed
# 168600000 lines processed
# 168800000 lines processed
# 169000000 lines processed
# 169200000 lines processed
# 169400000 lines processed
# 169600000 lines processed
# 169800000 lines processed
# 170000000 lines processed
# 170200000 lines processed
# 170400000 lines processed
# 170600000 lines processed
# 170800000 lines processed
# 171000000 lines processed
# 171200000 lines processed
# 171400000 lines processed
# 171600000 lines processed
# 171800000 lines processed
# 172000000 lines processed
# 172200000 lines processed
# 172400000 lines processed
# 172600000 lines processed
# 172800000 lines processed
# 173000000 lines processed
# 173200000 lines processed
# 173400000 lines processed
# 173600000 lines processed
# 173800000 lines processed
# 174000000 lines processed
# 174200000 lines processed
# 174400000 lines processed
# 174600000 lines processed
# 174800000 lines processed
# 175000000 lines processed
# 175200000 lines processed
# 175400000 lines processed
# 175600000 lines processed
# 175800000 lines processed
# 176000000 lines processed
# 176200000 lines processed
# 176400000 lines processed
# 176600000 lines processed
# 176800000 lines processed
# 177000000 lines processed
# 177200000 lines processed
# 177400000 lines processed
# 177600000 lines processed
# 177800000 lines processed
# 178000000 lines processed
# 178200000 lines processed
# 178400000 lines processed
# 178600000 lines processed
# 178800000 lines processed
# 179000000 lines processed
# 179200000 lines processed
# 179400000 lines processed
# 179600000 lines processed
# 179800000 lines processed
# 180000000 lines processed
# 180200000 lines processed
# 180400000 lines processed
# 180600000 lines processed
# 180800000 lines processed
# 181000000 lines processed
# 181200000 lines processed
# 181400000 lines processed
# 181600000 lines processed
# 181800000 lines processed
# 182000000 lines processed
# 182200000 lines processed
# 182400000 lines processed
# 182600000 lines processed
# 182800000 lines processed
# 183000000 lines processed
# 183200000 lines processed
# 183400000 lines processed
# 183600000 lines processed
# 183800000 lines processed
# 184000000 lines processed
# 184200000 lines processed
# 184400000 lines processed
# 184600000 lines processed
# 184800000 lines processed
# 185000000 lines processed
# 185200000 lines processed
# 185400000 lines processed
# 185600000 lines processed
# 185800000 lines processed
# 186000000 lines processed
# 186200000 lines processed
# 186400000 lines processed
# 186600000 lines processed
# 186800000 lines processed
# 187000000 lines processed
# 187200000 lines processed
# 187400000 lines processed
# 187600000 lines processed
# 187800000 lines processed
# 188000000 lines processed
# 188200000 lines processed
# 188400000 lines processed
# 188600000 lines processed
# 188800000 lines processed
# 189000000 lines processed
# 189200000 lines processed
# 189400000 lines processed
# 189600000 lines processed
# 189800000 lines processed
# 190000000 lines processed
# 190200000 lines processed
# 190400000 lines processed
# 190600000 lines processed
# 190800000 lines processed
# 191000000 lines processed
# 191200000 lines processed
# 191400000 lines processed
# 191600000 lines processed
# 191800000 lines processed
# 192000000 lines processed
# 192200000 lines processed
# 192400000 lines processed
# 192600000 lines processed
# 192800000 lines processed
# 193000000 lines processed
# 193200000 lines processed
# 193400000 lines processed
# 193600000 lines processed
# 193800000 lines processed
# 194000000 lines processed
# 194200000 lines processed
# 194400000 lines processed
# 194600000 lines processed
# 194800000 lines processed
# 195000000 lines processed
# 195200000 lines processed
# 195400000 lines processed
# 195600000 lines processed
# 195800000 lines processed
# 196000000 lines processed
# 196200000 lines processed
# 196400000 lines processed
# 196600000 lines processed
# 196800000 lines processed
# 197000000 lines processed
# 197200000 lines processed
# 197400000 lines processed
# 197600000 lines processed
# 197800000 lines processed
# 198000000 lines processed
# 198200000 lines processed
# 198400000 lines processed
# 198600000 lines processed
# 198800000 lines processed
# 199000000 lines processed
# 199200000 lines processed
# 199400000 lines processed
# 199600000 lines processed
# 199800000 lines processed
# 200000000 lines processed
# 200200000 lines processed
# 200400000 lines processed
# 200600000 lines processed
# 200800000 lines processed
# 201000000 lines processed
# 201200000 lines processed
# 201400000 lines processed
# 201600000 lines processed
# 201800000 lines processed
# 202000000 lines processed
# 202200000 lines processed
# 202400000 lines processed
# 202600000 lines processed
# 202800000 lines processed
# 203000000 lines processed
# 203200000 lines processed
# 203400000 lines processed
# 203600000 lines processed
# 203800000 lines processed
# 204000000 lines processed
# 204200000 lines processed
# 204400000 lines processed
# 204600000 lines processed
# 204800000 lines processed
# 205000000 lines processed
# 205200000 lines processed
# 205400000 lines processed
# 205600000 lines processed
# 205800000 lines processed
# 206000000 lines processed
# 206200000 lines processed
# 206400000 lines processed
# 206600000 lines processed
# 206800000 lines processed
# 207000000 lines processed
# 207200000 lines processed
# 207400000 lines processed
# 207600000 lines processed
# 207800000 lines processed
# 208000000 lines processed
# 208200000 lines processed
# 208400000 lines processed
# 208600000 lines processed
# 208800000 lines processed
# 209000000 lines processed
# 209200000 lines processed
# 209400000 lines processed
# 209600000 lines processed
# 209800000 lines processed
# 210000000 lines processed
# 210200000 lines processed
# 210400000 lines processed
# 210600000 lines processed
# 210800000 lines processed

# %% [markdown]
# **Step 4:** Calculated the median of mean maximum trailing zeros.

# %%
k = 3
average_zeros = [np.mean(max_zero[i:i+k]) for i in range(0,40,k)]
np.median(average_zeros)
# Out:
# 26.833333333333336

# %% [markdown]
# **Step 5:** Saved the file to CSV

# %%
averages = csv.writer(open("averages.csv",'w'), delimiter = ',', quoting = csv.QUOTE_ALL)
averages.writerow(average_zeros)
# Out:
# 43

# %% [markdown]
# **Step 6:** Estimated number of unique quotes

# %%
unique = 2 ** np.median(average_zeros)
unique
# Out:
# 119574401.82690892

# %% [markdown]
# ### Question 4
#
# Bloom Filter

# %% [markdown]
# **Step 1:** Imported all the necessary packages, and retrieved file list.

# %%
from bitarray import bitarray
import glob
import pyhash
import numpy as np
import sklearn
from sklearn.utils.murmurhash import murmurhash3_32

files = glob.glob("./Q2/*")
train_file = files[1]
test_file = files[0]

# %% [markdown]
# **Step 2:** Set the value of m as 350000, and built a bitarray of the same size, and set everything as false

# %%
m = 350000
bit = bitarray(m)
bit.setall(False)

# %% [markdown]
# **Step 3:** Built a function to count the number of lines in our files

# %%
def count(file):
    a = 0
    with open(file, 'r', encoding = 'utf8') as f:
        for line in f:
            a += 1
    return a

# %%
count_train = count(train_file)
print(count_train)

count_test = count(test_file)
print(count_test)
# Out:
# 229943
# 2636692

# %% [markdown]
# **Step 4:** Calculated the optimal "k" hash functions on the basis of the length of bitarray m

# %%
k = (count_test/m)*np.log(2)
k
# Out:
# 5.2217589308713235

# %% [markdown]
# **Step 5:** Found the value, and using the round value (k = 5). Implemented five hash functions (Murmur Hash, FNV Hash, XX Hash, Spooky Hash, and Farm Fingerprint Hash), calculated mod m of the value, and set the value of bitarray as true for the corresponding index value as the output of the computation.
#
# Trained the bitarray through the training set of only spams.

# %%
with open(train_file, 'r', encoding = 'utf8') as f:
    for line in f:
        murmur = murmurhash3_32(line, positive = True) % m
        fnv_32 = pyhash.fnv1_32()(line) % m
        xx_32 = pyhash.xx_32()(line) % m
        spooky_32 = pyhash.spooky_32()(line) % m
        farm_fingerprint32 = pyhash.farm_fingerprint_32()(line) % m
        bit[murmur] = True
        bit[fnv_32] = True
        bit[xx_32] = True
        bit[spooky_32] = True
        bit[farm_fingerprint32] = True

# %% [markdown]
# **Step 6:** Tried the same on the testing set, and depending on whether we get the higher count of True than False, the count of filter_in (unblocked) and filter_out (blocked).

# %%
filter_in = 0
filter_out = 0
with open(test_file, 'r', encoding = 'utf8') as f:
    for line in f:
        murmur = murmurhash3_32(line, positive = True) % m
        fnv_32 = pyhash.fnv1_32()(line) % m
        xx_32 = pyhash.xx_32()(line) % m
        spooky_32 = pyhash.spooky_32()(line) % m
        farm_fingerprint32 = pyhash.farm_fingerprint_32()(line) % m
        a = [bit[murmur], bit[fnv_32], bit[xx_32], bit[spooky_32], bit[farm_fingerprint32]]
        if a.count(False) < a.count(True):
            filter_out += 1
        else:
            filter_in += 1

# %% [markdown]
# **Step 7:** Calculated the false positive rate, which came out to be 0.04%

# %%
false_positive = filter_in / (filter_in + filter_out)
fpr = false_positive * 100
print("False Positive Rate:")
print(fpr)
# Out:
# False Positive Rate:
# 0.04460134137775667
